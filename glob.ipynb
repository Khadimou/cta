# %%
import glob

# %%
glob.glob('Data/*/*.h5',recursive=True)
# Out:
# ['Data/testing/dl1v06_reorganized_gamma_20deg_180deg_run607___cta-prod5-lapalma_4LSTs_MAGIC_desert-2158m_mono_off0.4.h5',
#  'Data/testing/dl1v06_reorganized_gamma_20deg_180deg_run736___cta-prod5-lapalma_4LSTs_MAGIC_desert-2158m_mono_off0.4.h5',
#  'Data/testing/dl1v06_reorganized_gamma_20deg_180deg_run174___cta-prod5-lapalma_4LSTs_MAGIC_desert-2158m_mono_off0.4.h5',
#  'Data/testing/dl1v06_reorganized_gamma_20deg_180deg_run531___cta-prod5-lapalma_4LSTs_MAGIC_desert-2158m_mono_off0.4.h5',
#  'Data/testing/dl1v06_reorganized_gamma_20deg_180deg_run635___cta-prod5-lapalma_4LSTs_MAGIC_desert-2158m_mono_off0.4.h5',
#  'Data/testing/dl1v06_reorganized_gamma_20deg_180deg_run658___cta-prod5-lapalma_4LSTs_MAGIC_desert-2158m_mono_off0.4.h5',
#  'Data/testing/dl1v06_reorganized_gamma_20deg_180deg_run120___cta-prod5-lapalma_4LSTs_MAGIC_desert-2158m_mono_off0.4.h5',
#  'Data/testing/dl1v06_reorganized_gamma_20deg_180deg_run177___cta-prod5-lapalma_4LSTs_MAGIC_desert-2158m_mono_off0.4.h5',
# ...

# %%
glob.glob?
# Out:
# Signature: glob.glob(pathname, *, recursive=False)
# Docstring:
# Return a list of paths matching a pathname pattern.
#
# The pattern may contain simple shell-style wildcards a la
# fnmatch. However, unlike fnmatch, filenames starting with a
# dot are special cases that are not matched by '*' and '?'
# patterns.
#
# If recursive is true, the pattern '**' will match any files and
# zero or more directories and subdirectories.
# File:      ~/miniconda3/envs/CTA/lib/python3.9/glob.py
# Type:      function
